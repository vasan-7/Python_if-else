# %%
#1. Write an `if` statement that checks if a variable `x` is greater than 10
x = int(input("Enter your number:"))
if x > 10:
    print("x is greater than 10")
else:
    print("Please re enter your number")

# %%
#2. Write an `if` statement that checks if a variable `y` is less than or equal to 5
y = int(input("Enter your number:"))
if y <= 5:
    print("y is less than or equal to 5")
# Out:
# Enter your number: 5
# y is less than or equal to 5

# %%
#3. Write an `if` statement that checks if a string `name` is equal to "Alice"
name = str(input("Enter your name:"))
if name == "Alice":
    print("your name is equal to Alice")
# Out:
# Enter your name: Alice
# your name is equal to Alice

# %%
#4. Write an `if` statement that checks if a number `num` is even
num = int(input("Enter your number:"))
if num % 2 == 0:
    print("number is even")
# Out:
# Enter your number: 10
# number is even

# %%
#5. Write an `if` statement that checks if a variable `z` is positive
z = int(input("Enter your number:"))
if z > 0:
    print("z is positive")
# Out:
# Enter your number: 1
# z is positive

# %%
# Write an `if` statement that checks if a list `my_list` is not empty.
my_list = [1,2,3]
if my_list:
    print("my list is not empty")
# Out:
# my list is not empty

# %%
#7. Write an `if` statement that checks if a variable `a` is between 1 and 100
a = int(input("Enter your number:"))
if 1 <= a <= 100:
    print("a is between 1 and 100")
# Out:
# Enter your number: 1
# a is between 1 and 100

# %%
#8. Write an `if` statement that checks if a string `password` contains "@"
password = str(input("Enter your password:"))
if password == "@":
    print("your password contains @")
# Out:
# Enter your password: @
# your password contains @

# %%
#9. Write an `if` statement that checks if a number `b` is a multiple of 5
b = int(input("Enter your number:"))
if b % 5 ==0:
    print(b, "b is multiple of 5")
# Out:
# Enter your number: 20
# 20 b is multiple of 5

# %%
#10. Write an `if` statement that checks if a string `s` starts with "Hello".
s = str(input("Enter your string:"))
if s.startswith("Hello"):
    print("string starts with hello")
# Out:
# Enter your string: hello world

# %%
#11. Write a nested `if` statement to check if `x` is greater than 10 and if `y` is less than 5.
x=12
y=3
if x > 10:
    if y < 5:
        print(x,y, "x is greater than 10 and y is less than 5")
# Out:
# 12 3 x is greater than 10 and y is less than 5

# %%
#12. Write a nested `if` statement to check if a variable `age` is between 18 and 65 and if `citizen` is True.
age = 21
citizen = True
if 18 <= age <= 65:
    if citizen == True:
        print(age, citizen, "`age` is between 18 and 65 and if `citizen` is True.")
# Out:
# 21 True `age` is between 18 and 65 and if `citizen` is True.

# %%
#13. Write a nested `if` statement to check if `score` is greater than 90 and if `attendance` is greater than 80.
score = 95
attendance = 85
if score > 90:
    if attendance > 80:
        print(score, attendance, "score is greater than 90 and attendanceis greater than 80.")
# Out:
# 95 85 score is greater than 90 and attendanceis greater than 80.

# %%
#14. Write a nested `if` statement to check if a variable `temp` is below 0 and if `weather` is "snowy".
temp = -1
weather = "snowy"
if temp < 0:
    if weather == "snowy":
        print(temp, weather, "temp is below 0 and weather is snowy")
# Out:
# -1 snowy temp is below 0 and weather is snowy

# %%
#15. Write a nested `if` statement to check if a variable `grade` is "A" and if `passed` is True.
grade = "A"
passed = True
if grade == "A":
    if passed:
        print(grade, "student is passed")
# Out:
# A student is passed
